# %% [markdown]
# <a href="https://colab.research.google.com/github/mausLe/falldetection_openpifpaf/blob/master/NOTEBOOK_falldetection_openpifpaf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python3 --version
# Out:
# Python 3.6.9

# %%
# !env PYTHONPATH=
# Out:
# CUDNN_VERSION=7.6.5.32
# __EGL_VENDOR_LIBRARY_DIRS=/usr/lib64-nvidia:/usr/share/glvnd/egl_vendor.d/
# LD_LIBRARY_PATH=/usr/lib64-nvidia
# CLOUDSDK_PYTHON=python3
# _=/usr/bin/env
# LANG=en_US.UTF-8
# HOSTNAME=23efcaf5a7ce
# OLDPWD=/
# CLOUDSDK_CONFIG=/content/.config
# NVIDIA_VISIBLE_DEVICES=all
# DATALAB_SETTINGS_OVERRIDES={"kernelManagerProxyPort":6000,"kernelManagerProxyHost":"172.28.0.3","jupyterArgs":["--ip=\"172.28.0.2\""]}
# ENV=/root/.bashrc
# PAGER=cat
# NCCL_VERSION=2.7.8
# TF_FORCE_GPU_ALLOW_GROWTH=true
# JPY_PARENT_PID=25
# NO_GCE_CHECK=True
# PWD=/content
# HOME=/root
# LAST_FORCED_REBUILD=20201013
# CLICOLOR=1
# DEBIAN_FRONTEND=noninteractive
# LIBRARY_PATH=/usr/local/cuda/lib64/stubs
# GCE_METADATA_TIMEOUT=0
# GLIBCPP_FORCE_NEW=1
# TBE_CREDS_ADDR=172.28.0.1:8008
# TERM=xterm-color
# SHELL=/bin/bash
# GCS_READ_CACHE_BLOCK_SIZE_MB=16
# PYTHONWARNINGS=ignore:::pip._internal.cli.base_command
# MPLBACKEND=module://ipykernel.pylab.backend_inline
# ...

# %% [markdown]
# # Install Miniconda
# Tutorial: https://towardsdatascience.com/conda-google-colab-75f7c867a522
# Install miniconda directly into /usr/local to ensure all Conda dependencies will be available to use

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which conda
# !conda --version
# Out:
# /usr/local/bin/conda
# conda 4.5.4

# %% [markdown]
# # Updating Conda
# Update Conda and dependencies to the most recent version

# %%
# %%bash
# conda install --channel defaults conda python=3.7.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.7.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ruamel_yaml-0.15.87        |   py37h7b6447c_1         253 KB
#     pyopenssl-19.1.0           |             py_1          47 KB
#     idna-2.10                  |             py_0          56 KB
#     openssl-1.1.1h             |       h7b6447c_0         3.8 MB
#     pycparser-2.20             |             py_2          94 KB
#     six-1.15.0                 |             py_0          13 KB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     conda-package-handling-1.7.2|   py37h03888b9_0         977 KB
#     yaml-0.2.5                 |       h7b6447c_0          87 KB
#     chardet-3.0.4              |        py37_1003         173 KB
# ...

# %%
# %%bash
# which conda
# conda --version
# python --version
# Out:
# /usr/local/bin/conda
# conda 4.9.0
# Python 3.7.9

# %% [markdown]
# # Appending to the `sys.path`

# %%
import sys
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %% [markdown]
# # List Python Conda dependencies

# %%
# !ls /usr/local/lib/python3.7/site-packages
# Out:
# brotli
# brotlipy-0.7.0-py3.7.egg-info
# certifi
# certifi-2020.6.20-py3.7.egg-info
# cffi
# cffi-1.14.3.dist-info
# _cffi_backend.cpython-37m-x86_64-linux-gnu.so
# chardet
# chardet-3.0.4.dist-info
# conda
# conda-4.9.0-py3.7.egg-info
# conda_env
# conda_package_handling
# conda_package_handling-1.7.2.dist-info
# cryptography
# cryptography-3.1.1.dist-info
# _distutils_hack
# distutils-precedence.pth
# easy_install.py
# idna
# idna-2.10.dist-info
# OpenSSL
# pip
# pip-20.2.3-py3.7.egg-info
# pkg_resources
# __pycache__
# pycosat-0.6.3-py3.7.egg-info
# pycosat.cpython-37m-x86_64-linux-gnu.so
# pycparser
# pycparser-2.20.dist-info
# pyOpenSSL-19.1.0.dist-info
# PySocks-1.7.1.dist-info
# README.txt
# requests
# requests-2.24.0.dist-info
# ruamel_yaml
# ruamel_yaml-0.15.87-py3.7.egg-info
# setuptools
# setuptools-50.3.0.post20201006-py3.7.egg-info
# six-1.15.0.dist-info
# six.py
# sockshandler.py
# socks.py
# test_data
# test_pycosat.py
# tqdm
# tqdm-4.50.2.dist-info
# urllib3
# ...

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.77/site-packages"))

# %%
# !nvidia-smi
# Out:
# Mon Oct 19 17:12:50 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# Currently, I use pre-installed CUDA 10.0

# %%
# !python --version
# Out:
# Python 3.7.9

# %%
# %%bash
# conda create --name falldetection_openpifpaf python=3.7.9 # or 3.7.9
# conda activate falldetection_openpifpaf
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/falldetection_openpifpaf
#
#   added / updated specs:
#     - python=3.7.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB
#     ca-certificates-2020.10.14 |                0         121 KB
#     certifi-2020.6.20          |           py37_0         156 KB
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         568 KB
#     libedit-3.1.20191231       |       h14c3975_1         116 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         5.1 MB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         3.1 MB
#     ncurses-6.2                |       he6710b0_1         817 KB
#     openssl-1.1.1h             |       h7b6447c_0         2.5 MB
# ...

# %%
pwd
# Out:
# '/content'

# %%
# !git clone https://github.com/cwlroda/falldetection_openpifpaf.git
# Out:
# Cloning into 'falldetection_openpifpaf'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 848 (delta 4), reused 0 (delta 0), pack-reused 839
# Receiving objects: 100% (848/848), 160.83 MiB | 48.88 MiB/s, done.
# Resolving deltas: 100% (370/370), done.

# %%
# !pip install openpifpaf
# Out:
# ...
#      |████████████████████████████████| 223 kB 5.4 MB/s
# ...
#   Using cached numpy-1.19.2-cp37-cp37m-manylinux2010_x86_64.whl (14.5 MB)
# ...
#      |████████████████████████████████| 64 kB 3.5 MB/s
# ...
#      |████████████████████████████████| 25.9 MB 114 kB/s
# ...
#      |████████████████████████████████| 748.8 MB 18 kB/s
# ...
#      |████████████████████████████████| 5.9 MB 70.8 MB/s
# ...
#      |████████████████████████████████| 2.2 MB 77.3 MB/s
# ...
#      |████████████████████████████████| 829 kB 68.2 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 71.2 MB/s
# ...
#   Created wheel for openpifpaf: filename=openpifpaf-0.11.9-cp37-cp37m-linux_x86_64.whl size=473046 sha256=daf638245adb6d13eab025d779c3cf7716a31deb7071f10fb57c3df5eda210a1
#   Stored in directory: /root/.cache/pip/wheels/69/3e/f5/7f1b8b2f9d011d4e65fe791ae596efee5b8d4b15f19800b92b
# ...

# %%
! which conda
# Out:
# /usr/local/bin/conda

# %%
! cd /content/
! ls
# Out:
# falldetection_openpifpaf  Miniconda3-4.5.4-Linux-x86_64.sh  sample_data

# %%
! rm -rf /usr/local/lib/python3.7/site-packages/openpifpaf/*

# %%
! ls /usr/local/lib/python3.7/site-packages/openpifpaf

# %%
! cp -R /content/falldetection_openpifpaf/* /usr/local/lib/python3.7/site-packages/openpifpaf

# %%
# %cd /usr/local/lib/python3.7/site-packages/openpifpaf
# Out:
# /usr/local/lib/python3.7/site-packages/openpifpaf

# %% [markdown]
# Install Dependencies

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 13.1 MB 97 kB/s
# ...
#      |████████████████████████████████| 28.2 MB 76 kB/s
# ...
#      |████████████████████████████████| 227 kB 53.3 MB/s
# ...
#      |████████████████████████████████| 88 kB 8.2 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.7 MB/s
# ...

# %%
# !python3 -m openpifpaf.video --show
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/runpy.py", line 183, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/local/lib/python3.7/runpy.py", line 109, in _get_module_details
#     __import__(pkg_name)
#   File "/usr/local/lib/python3.7/site-packages/openpifpaf/__init__.py", line 9, in <module>
#     from . import decoder
#   File "/usr/local/lib/python3.7/site-packages/openpifpaf/decoder/__init__.py", line 4, in <module>
#     from .cif_hr import CifHr, CifDetHr
#   File "/usr/local/lib/python3.7/site-packages/openpifpaf/decoder/cif_hr.py", line 9, in <module>
#     from .. import visualizer
#   File "/usr/local/lib/python3.7/site-packages/openpifpaf/visualizer/__init__.py", line 3, in <module>
#     from .base import BaseVisualizer
#   File "/usr/local/lib/python3.7/site-packages/openpifpaf/visualizer/base.py", line 5, in <module>
#     from .. import show
# ...

# %% [markdown]
# # Original repo
# https://github.com/cwlroda/falldetection_openpifpaf

# %%
# !conda create --name falldetection_openpifpaf python=3.6.9
# Out:
# /bin/bash: conda: command not found
